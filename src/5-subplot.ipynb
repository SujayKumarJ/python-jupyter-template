# %% [markdown]
# ### Exercise 5: Subplot Layout

# %%
# TASK: Create a 2x2 subplot layout.
# Plot a line chart in the first subplot, a bar chart in the second, a scatter plot in the third, and a pie chart in the fourth.

# %%
import matplotlib.pyplot as plt

# Create a 2x2 subplot layout
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# 1. Line chart (first subplot)
x = [1, 2, 3, 4, 5]
y = [10, 12, 8, 14, 7]
axs[0, 0].plot(x, y, marker='o')
axs[0, 0].set_title('Line Chart')

# 2. Bar chart (second subplot)
categories = ['A', 'B', 'C', 'D']
values = [5, 7, 3, 6]
axs[0, 1].bar(categories, values, color='skyblue')
axs[0, 1].set_title('Bar Chart')

# 3. Scatter plot (third subplot)
x_scatter = [1, 2, 3, 4, 5]
y_scatter = [5, 15, 8, 12, 6]
axs[1, 0].scatter(x_scatter, y_scatter, color='green')
axs[1, 0].set_title('Scatter Plot')

# 4. Pie chart (fourth subplot)
labels = ['Python', 'Java', 'C++', 'JavaScript']
sizes = [40, 25, 20, 15]
axs[1, 1].pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
axs[1, 1].set_title('Pie Chart')
axs[1, 1].axis('equal')  # Equal aspect ratio ensures the pie chart is circular

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()
